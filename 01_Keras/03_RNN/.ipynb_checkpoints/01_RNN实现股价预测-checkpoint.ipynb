# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from sklearn.metrics import r2_score
# Out:
# Using TensorFlow backend.

# %%
train_data_frame = pd.read_csv('./data_01_train.csv')
print(train_data_frame.columns.values.tolist())
train_data = train_data_frame['close']

test_data_frame = pd.read_csv('./data_01_test.csv')
print(test_data_frame.columns.values.tolist())
test_data = test_data_frame['close']
# Out:
# ['date', 'open', 'high', 'low', 'close', 'volume']
# ['date', 'open', 'high', 'low', 'close', 'volume']

# %%
# 数据归一化
class MinMaxScaler:
    def __init__(self):
        self.min_num = None
        self.max_num = None

    def fit(self, data):
        self.max_num = np.max(data)
        self.min_num = np.min(data)

    def transform(self, data):
        return (data - self.min_num) / (self.max_num - self.min_num)

    def inverse_transform(self, data):
        return data * (self.max_num - self.min_num) + self.min_num
    
train_scaler = MinMaxScaler()
train_scaler.fit(train_data)
train_data_normalize = train_scaler.transform(train_data)

test_scaler = MinMaxScaler()
test_scaler.fit(test_data)
test_data_normalize = test_scaler.transform(test_data)

print(train_data[:10])
print(train_data_normalize[:10])
print(test_data[:10])
print(test_data_normalize[:10])
# Out:
# 0    28.78
# 1    29.23
# 2    29.26
# 3    28.50
# 4    28.67
# 5    26.76
# 6    26.94
# 7    26.72
# 8    26.72
# 9    25.93
# Name: close, dtype: float64
# 0    0.099027
# 1    0.107782
# 2    0.108366
# 3    0.093580
# 4    0.096887
# 5    0.059728
# 6    0.063230
# 7    0.058949
# 8    0.058949
# 9    0.043580
# Name: close, dtype: float64
# 0    53.33
# 1    53.83
# 2    54.74
# 3    54.45
# 4    53.95
# 5    55.10
# 6    55.65
# 7    56.22
# 8    55.27
# 9    56.74
# Name: close, dtype: float64
# 0    0.000000
# 1    0.012817
# 2    0.036145
# 3    0.028711
# 4    0.015893
# 5    0.045373
# 6    0.059472
# 7    0.074084
# 8    0.049731
# 9    0.087413
# Name: close, dtype: float64

# %%
# 每次使用前8个数据，预测第9个数据
def exchange_data(data, count=8):
    X = []
    y = []
    for index in range(len(data) - count):
        X.append(data[index:index + count])
        y.append(data[index + count])
    X = np.array(X)
    X = X.reshape(X.shape[0], X.shape[1], -1)
    y = np.array(y)
    return X, y

# %%
# 数据变型
X_train, y_train = exchange_data(data=train_data_normalize, count=8)
X_test, y_test = exchange_data(data=test_data_normalize, count=8)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (723, 8, 1) (723,) (174, 8, 1) (174,)

# %%
# 建立RNN模型
rnn_model = Sequential()
# 输入层
rnn_model.add(
    SimpleRNN(
        units=5,
        input_shape=(8, 1),
        activation='relu'
    )
)
# 输出层
rnn_model.add(
    Dense(
        units=1,
        activation='linear'
    )
)
# 设置损失函数和最优化方法
rnn_model.compile(
    loss='mean_squared_error',
    optimizer='adam'
)
# 查看模型结构
rnn_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 5)                 35
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 模型训练
rnn_model.fit(
    X_train, y_train,
    batch_size=100,
    epochs=200,
    verbose=1
)
# Out:
# Epoch 1/200
# 723/723 [==============================] - 0s 595us/step - loss: 0.1007
# Epoch 2/200
# 723/723 [==============================] - 0s 30us/step - loss: 0.0802
# Epoch 3/200
# 723/723 [==============================] - 0s 32us/step - loss: 0.0652
# Epoch 4/200
# 723/723 [==============================] - 0s 32us/step - loss: 0.
200
# 723/723 [==============================] - 0s 39us/step - loss: 3.7891e-04
# Epoch 181/200
# 723/723 [==============================] - 0s 51us/step - loss: 3.7909e-04
# Epoch 182/200
# 723/723 [==============================] - 0s 37us/step - loss: 3.7726e-04
# Epoch 183/200
# 723/723 [==============================] - 0s 32us/step - loss: 3.7782e-04
# Epoch 184/200
# 723/723 [==============================] - 0s 37us/step - loss: 3.7842e-04
# Epoch 185/200
# 723/723 [==============================] - 0s 48us/step - loss: 3.7499e-04
# Epoch 186/200
# 723/723 [==============================] - 0s 47us/step - loss: 3.7535e-04
# Epoch 187/200
# 723/723 [==============================] - 0s 43us/step - loss: 3.7521e-04
# Epoch 188/200
# 723/723 [==============================] - 0s 43us/step - loss: 3.7536e-04
# Epoch 189/200
# 723/723 [==============================] - 0s 41us/step - loss: 3.7401e-04
# Epoch 190/200
# 723/723 [==============================] - 0s 46us/step - loss: 3.7460e-04
# Epoch 191/200
# 723/723 [==============================] - 0s 36us/step - loss: 3.7284e-04
# Epoch 192/200
# 723/723 [==============================] - 0s 43us/step - loss: 3.7466e-04
# Epoch 193/200
# 723/723 [==============================] - 0s 34us/step - loss: 3.7221e-04
# Epoch 194/200
# 723/723 [==============================] - 0s 33us/step - loss: 3.7340e-04
# Epoch 195/200
# 723/723 [==============================] - 0s 36us/step - loss: 3.7211e-04
# Epoch 196/200
# 723/723 [==============================] - 0s 39us/step - loss: 3.7314e-04
# Epoch 197/200
# 723/723 [==============================] - 0s 40us/step - loss: 3.7190e-04
# Epoch 198/200
# 723/723 [==============================] - 0s 40us/step - loss: 3.7541e-04
# Epoch 199/200
# 723/723 [==============================] - 0s 39us/step - loss: 3.7240e-04
# Epoch 200/200
# 723/723 [==============================] - 0s 34us/step - loss: 3.7847e-04

# %%
# train score
y_train_src = train_scaler.inverse_transform(y_train)
y_train_predict = rnn_model.predict(X_train)
y_train_predict_src = train_scaler.inverse_transform(y_train_predict)
train_score = r2_score(y_true=y_train_src, y_pred=y_train_predict_src)
print(train_score)
# Out:
# 0.9961652373654785

# %%
# test score
y_test_src = test_scaler.inverse_transform(y_test)
y_test_predict = rnn_model.predict(X_test)
y_test_predict_src = test_scaler.inverse_transform(y_test_predict)
test_score = r2_score(y_true=y_test_src, y_pred=y_test_predict_src)
print(test_score)
# Out:
# 0.9740601975711113

# %%
# train
import matplotlib.pyplot as plt
plt.plot(train_data_frame['date'], train_data_frame['close'], color='b')

# y_train_predict_src = np.vstack([np.zeros(shape=(8, 1)), y_train_predict_src])
plt.plot(train_data_frame['date'], y_train_predict_src, color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-8dacd88a8627> in <module>()
#       4
#       5 y_train_predict_src = np.vstack([np.zeros(shape=(8, 1)), y_train_predict_src])
# ----> 6 plt.plot(train_data_frame['date'], y_train_predict_src, color='r')
#       7 plt.show()
#
# D:\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# D:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# D:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# D:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# D:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# D:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (731,) and (739, 1)

# %%
# test
plt.plot(test_data_frame['date'], test_data_frame['close'], color='b')

y_test_predict_src = np.vstack([np.zeros(shape=(8, 1)), y_test_predict_src])
plt.plot(test_data_frame['date'], y_test_predict_src, color='r')
plt.show()
